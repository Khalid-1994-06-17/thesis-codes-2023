# %%
# import libraries
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import math
import keras
from keras.preprocessing.sequence import TimeseriesGenerator

import warnings
warnings.filterwarnings("ignore")

import plotly.graph_objects as go

np.random.seed(1)
tf.random.set_seed(1)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed, Bidirectional

# %% [markdown]
# [Predicting Sequential Data using LSTM: An Introduction](https://towardsdatascience.com/time-series-forecasting-with-recurrent-neural-networks-74674e289816)

# %%
huwaei=pd.read_csv('training_100.csv')
huwaei['timestamp']=pd.to_datetime(huwaei['timestamp'])
huwaei.head() 
huwaei.tail()
# Out:
#                       timestamp  kpi_value  request_count  anomaly_label
# 20154 2020-08-28 01:56:00+02:00   0.998149          26467              0
# 20155 2020-08-28 01:57:00+02:00   0.998340          26502              0
# 20156 2020-08-28 01:58:00+02:00   0.998364          26887              0
# 20157 2020-08-28 01:59:00+02:00   0.998428          26712              0
# 20158 2020-08-28 02:00:00+02:00   0.997407          29694              0

# %%
kpi=huwaei['kpi_value']
timestamp=huwaei['timestamp']
label=huwaei['anomaly_label']

# %%
fig, ax2d = plt.subplots(figsize=(40,10))
ax2a = ax2d.twinx()
ax2d.plot(timestamp, kpi, color='blue')
ax2a.plot(timestamp, label, color='red', linewidth='1')
ax2d.set_xlabel('Time Stamp', fontsize=20)
ax2d.set_ylabel('KPI Value', fontsize=20)
ax2a.set_ylabel('Anomaly Label', fontsize=20)

plt.grid()

plt.title('Huwaei Dataset', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Huwaei Dataset')

# %%
print(f"Length of full data: {len(huwaei)}")
# Out:
# Length of full data: 20159

# %%
x=huwaei[0:50]
y=huwaei[100:150]

x=pd.DataFrame(x)
y=pd.DataFrame(y)

frames=[x,y]
results=pd.concat(frames)
results
# Out:
#                     timestamp  kpi_value  request_count  anomaly_label
# 0   2020-08-14 02:00:00+02:00   0.998755          24908              0
# 1   2020-08-14 02:01:00+02:00   0.997683          25029              0
# 2   2020-08-14 02:02:00+02:00   0.998341          24115              0
# 3   2020-08-14 02:03:00+02:00   0.998211          24031              0
# 4   2020-08-14 02:04:00+02:00   0.998403          23790              0
# ..                        ...        ...            ...            ...
# 145 2020-08-14 04:25:00+02:00   0.997948          20954              0
# 146 2020-08-14 04:26:00+02:00   0.991813          21132              0
# 147 2020-08-14 04:27:00+02:00   0.998292          21080              0
# 148 2020-08-14 04:28:00+02:00   0.998045          20967              0
# 149 2020-08-14 04:29:00+02:00   0.997559          21709              0
#
# [100 rows x 4 columns]

# %%
arr=np.where(label==1)
arr
# Out:
# (array([ 4448,  4449,  4450,  4451,  4452,  4453,  4454,  4455,  4456,
#          4457,  4458,  4459,  4460,  4461,  4462,  4463,  4464,  4465,
#          4466,  4467,  4468,  4469,  4470,  4471,  4472,  4473,  4474,
#          4475,  4476,  4477,  4478,  4479,  4480,  4481,  4482,  4483,
#          4484,  4485,  4486,  4487,  4488,  4489,  4490,  4491,  4492,
#          4493,  4494,  4495,  4496,  4497,  4498,  4499,  4500,  4501,
#          4502,  4503,  4504,  4505,  4506,  4507,  4508,  4509,  4510,
#          4511,  4512,  4513,  4514,  4515,  4516,  4517,  4518,  4519,
#          4520,  4521,  4522,  4523,  4524,  4525,  4526,  4527,  4528,
#          4529,  4530,  4531,  4532,  4533,  4534,  4535,  4536,  4537,
#          4538,  4539,  4540,  4541,  4542,  4543,  4544,  4545,  4546,
#          4547,  4548,  4549,  4550,  4551,  4552,  4553,  4554,  4555,
#          4556,  4557,  4558,  4559,  4560,  4561,  4562,  4563,  4564,
#          4565,  4566,  4567,  4568,  4569,  4570,  4571,  4572,  4573,
#          4574,  4575,  4576,  4577,  4578,  4579,  4580,  4581,  4582,
#          4583,  4584,  4585,  4586,  4587,  4588,  4589,  4590,  4591,
#          4592,  4593,  4594,  4595,  4596,  4597,  4598,  4599,  4600,
#          4601,  4602,  4603,  4604,  4605,  4606,  4607,  4608,  4609,
#          4610,  4611,  4612,  4613,  4614,  4615,  4616,  4617,  4618,
#          4619,  4620,  4621,  4622,  4623,  4624,  4625,  4626,  4627,
#          4628,  4629,  4630,  4631,  4632,  4633,  4634,  4635,  4636,
#          4637,  4638,  4639,  4640,  4641,  4642,  4643,  4644,  4645,
#          7543,  7544,  7545,  7546,  7547,  7548,  7549,  7550,  7551,
#          7552,  7553,  7554,  7555,  7556,  7557,  7558,  7559,  7560,
#          7561,  7562,  7563,  7564,  7565,  7566,  7567,  7568,  7569,
#          7570,  7571,  7572,  7573,  7574,  7575,  7576,  7577,  7578,
#          7579,  7580,  7581,  7582,  7583,  7584,  7585,  7586,  7587,
#          7588,  7589,  7590,  7591,  7592,  7593,  7594,  7595, 11649,
#         11650, 11651, 11652, 11653, 11654, 11655, 11656, 11657, 11658,
#         11659, 11660, 11661, 11662, 11663, 11664, 11665, 11666, 11667,
#         11668, 11669, 11670, 11671, 11672, 11673, 11674, 11675, 11676,
#         11677, 11678, 11679, 11680, 11681, 11682, 11683, 11684, 11685,
#         11686, 11687, 11688, 11689, 11690, 11691, 11692, 11693, 11694,
#         11695, 11696, 11697, 11698, 11699, 11700, 11701, 11702, 11703,
#         11704, 11705, 11706, 11707, 11708, 11709, 11710, 11711, 11712,
#         11713, 11714, 11715, 11716, 11717, 11718, 11719, 11720, 11721,
#         11722, 11723, 11724, 11725, 11726, 11727, 11728, 11729, 11730,
#         11731, 11732, 11733, 11734, 11735, 11736, 11737, 11738, 11739,
#         11740, 11741, 11742, 11743, 11744, 11745, 11746, 11747, 11748,
#         11749, 11750, 11751, 11752, 11753, 11754, 11755, 11756, 11757,
#         11758, 11759, 11760, 11761, 11762, 11763, 11764, 11765, 11766,
#         11767, 11768, 11769, 11770, 11771, 11772, 11773, 11774, 11775,
#         11776, 11777, 11778, 11779, 11780, 11781, 11782, 11783, 11784,
#         11785, 11786, 11787, 11788, 11789, 11790, 11791, 11792, 11793,
#         11794, 11795, 11796, 11797, 11798, 11799, 11800, 11801, 11802,
#         11803, 11804, 11805, 11806, 11807, 11808, 11809, 11810, 11811,
#         11812, 11813, 11814, 11815, 11816, 11817, 11818, 11819, 11820,
#         11821, 11822, 11823, 11824, 11825, 11826, 11827, 11828, 11829,
#         11830, 11831, 11832, 11833, 11834, 11835, 11836, 11837, 11838,
#         11839, 11840, 11841, 11842, 11843, 11844, 11845, 11846, 11847,
#         11848, 11849, 11850, 11851, 11852, 11853, 11854, 11855, 11856,
#         11857, 11858, 11859, 11860, 11861, 11862, 11863, 11864, 11865,
#         11866, 11867, 11868, 11869, 11870, 11871, 11872, 11873, 11874,
#         11875, 11876, 11877, 11878, 11879, 11880, 11881, 11882, 11883,
#         11884, 11885, 11886, 11887, 11888, 11889, 11890, 11891, 11892,
#         11893, 11894, 11895, 11896, 11897, 11898, 11899, 11900, 11901,
#         11902, 11903, 11904, 11905, 11906, 11907, 11908, 11909, 11910,
#         11911, 11912, 11913, 11914, 11915, 11916, 11917, 11918, 11919,
#         11920, 11921, 11922, 11923, 11924, 11925, 11926, 11927, 11928,
#         11929, 11930, 11931, 11932, 11933, 11934, 11935, 11936, 11937,
#         11938, 11939, 11940, 11941, 11942, 11943, 11944, 11945, 11946,
#         11947, 11948, 11949, 11950, 11951, 11952, 11953, 11954, 11955,
#         11956, 11957, 11958, 11959, 11960, 11961, 11962, 11963, 11964,
#         11965, 11966, 11967, 11968, 11969, 11970, 11971, 11972, 11973,
#         11974, 11975, 11976, 11977, 11978, 11979, 11980, 11981, 11982,
#         11983, 11984, 11985, 11986, 11987, 11988, 11989, 11990, 11991,
#         11992, 11993, 11994, 11995, 11996, 11997, 11998, 11999, 12000,
#         12001, 12002, 12003, 12004, 12005, 12006, 12007, 12008, 12009,
#         12010, 12011, 12012, 12013, 12014, 12015, 12016, 12017, 12018,
#         12019, 12020, 12021, 12022, 12023, 12024, 12025, 12026, 12027,
#         12028, 12029, 12030, 12031, 12032, 12033, 12034, 12035, 12036,
#         12037, 12038, 12039, 12040, 12041, 12042, 12043, 12044, 12045,
#         12046, 12047, 12048, 12049, 12050, 12051, 12052, 12053, 12054,
#         12055, 12056, 12057, 13369, 13370, 13371, 13372, 13373, 13374,
#         13375, 13376, 13377, 13378, 13379, 13380, 13381, 13382, 13383,
#         13384, 13385, 13386, 13387, 13388, 13389, 13390, 13391, 13392,
#         13393, 13394, 13395, 13396, 13397, 13398]),)

# %%
train=huwaei[5002:7001]
test=huwaei[7002:8001]

# %%
label2=label[5002:8001]
label2
print(f"Dataset Length: {len(train)+len(test)}")
# Out:
# Dataset Length: 2998

# %%
fig, ax2d = plt.subplots(figsize=(40,10))
ax2a = ax2d.twinx()
ax2d.plot(train['timestamp'], train['kpi_value'], color='blue')
ax2d.plot(test['timestamp'], test['kpi_value'], color='red')
ax2a.plot(timestamp[5002:8001], label2, color='green', linewidth='1.5')
ax2d.set_xlabel('Time Stamp', fontsize=20)
ax2d.set_ylabel('KPI Value', fontsize=20)
ax2a.set_ylabel('Anomaly Label', fontsize=20)

plt.grid()

plt.title('Huwaei Dataset', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Huwaei Dataset')

# %%
print(f"Total Training Samples: {len(train)}")
print(f"Total Testing Samples: {len(test)}")
print(f"Training Percentage: {round((100*len(train))/(len(train)+len(test)),2)} %")
# Out:
# Total Training Samples: 1999
# Total Testing Samples: 999
# Training Percentage: 66.68 %

# %%
train=train['kpi_value']
train=np.array(train)

# %%
test=test['kpi_value']
test=np.array(test)

# %%
print(train)
# Out:
# [0.98922127 0.98423287 0.98910048 ... 0.99557552 0.99568425 0.99654345]

# %%
print(test)
# Out:
# [0.9962785  0.99646692 0.99720748 0.99620725 0.99598922 0.99653587
#  0.99580369 0.99675494 0.99596104 0.9962718  0.99648336 0.99663219
#  0.99628555 0.99740783 0.996043   0.99598516 0.99610041 0.99650981
#  0.99275516 0.99133587 0.99309781 0.99394865 0.99433638 0.99548405
#  0.99591049 0.99604765 0.99561003 0.99578804 0.99606052 0.99594737
#  0.99598847 0.99592703 0.99634077 0.99647556 0.9962804  0.99570766
#  0.99569917 0.99663167 0.99566729 0.99627645 0.99631916 0.99643524
#  0.99641095 0.99661552 0.99711272 0.99658628 0.99709462 0.99725907
#  0.99760766 0.99712628 0.99654219 0.99655969 0.99690518 0.99654567
#  0.99812246 0.99645189 0.99627869 0.99652922 0.99723785 0.99780335
#  0.99704781 0.99696393 0.99737257 0.99651925 0.99727977 0.99757357
#  0.99649551 0.99733869 0.99749436 0.99788466 0.99660526 0.99771401
#  0.99745123 0.99767543 0.99780862 0.9974218  0.99759839 0.99798133
#  0.99315241 0.98958779 0.9933378  0.9939916  0.99402433 0.99547014
#  0.99621349 0.9958906  0.99531932 0.99561092 0.99609255 0.99671578
#  0.99624267 0.99632015 0.99631557 0.99663408 0.99579695 0.99603848
#  0.99606335 0.99685426 0.99646947 0.99687221 0.99715112 0.99668962
#  0.99694582 0.99672146 0.99787582 0.99730839 0.99673056 0.99675093
#  0.99737499 0.99753433 0.99664044 0.99669386 0.99756452 0.99704553
#  0.9969459  0.99832912 0.99785122 0.99796118 0.99776824 0.99761987
#  0.99756487 0.99777273 0.9983654  0.99824774 0.99788548 0.99829773
#  0.99817827 0.99799906 0.9981748  0.9981673  0.99781116 0.99786771
#  0.99786492 0.99857353 0.99813314 0.99790777 0.99811629 0.99806734
#  0.9969079  0.99598999 0.99639484 0.99748039 0.9973341  0.99753664
#  0.99713491 0.99772624 0.99777927 0.9981773  0.99819376 0.99775477
#  0.9976692  0.99794112 0.99767698 0.99835992 0.99777099 0.99790795
#  0.99810356 0.99796291 0.99837581 0.99795774 0.99791777 0.99855613
#  0.99786491 0.99823742 0.9978926  0.99762442 0.99897801 0.99865119
#  0.99843001 0.99796043 0.99813614 0.99905224 0.99803576 0.99832556
#  0.99851295 0.99839525 0.99815594 0.99823485 0.99865914 0.99879822
#  0.9983634  0.99794736 0.99830693 0.99855885 0.998633   0.99838768
#  0.99855072 0.99833847 0.99856465 0.99840992 0.99843119 0.9985128
#  0.99862826 0.99827402 0.99889417 0.99878474 0.99877741 0.99856775
#  0.99817278 0.99843228 0.99784851 0.9979198  0.99838213 0.9982758
#  0.99812162 0.99817865 0.99457322 0.99840128 0.99631781 0.99599023
#  0.99811381 0.99841534 0.99822632 0.99842016 0.99865989 0.99831597
#  0.99873033 0.99840795 0.99880971 0.99874677 0.99821329 0.9987568
#  0.99843646 0.99845134 0.99872743 0.99843266 0.99811824 0.99855798
#  0.99831006 0.99857386 0.99847179 0.99851071 0.99860075 0.99838855
#  0.99911637 0.99885952 0.99766655 0.99870288 0.9980544  0.99882959
#  0.99886413 0.99887532 0.99857392 0.99868121 0.99866047 0.99882602
#  0.99845886 0.9976352  0.99902137 0.99893095 0.99882767 0.99858663
#  0.99876725 0.99914253 0.99793766 0.99877528 0.99933362 0.99872965
#  0.998362   0.99883173 0.99873732 0.99891008 0.99836576 0.99854233
#  0.99834469 0.99918418 0.99856739 0.99847689 0.99859646 0.99864266
#  0.99870451 0.99819567 0.99865448 0.99873192 0.99859635 0.99882994
#  0.99892129 0.99876499 0.9980269  0.9985461  0.99875921 0.99896715
#  0.99913447 0.99876005 0.99901365 0.99884994 0.99859888 0.99918811
#  0.99864098 0.99815025 0.99819672 0.99853653 0.99824994 0.99920789
#  0.99897221 0.99882544 0.9981347  0.99899695 0.99888796 0.99886805
#  0.99872296 0.99909227 0.99893571 0.99887151 0.99858956 0.99768218
#  0.99853778 0.99875347 0.99872849 0.99860901 0.99869048 0.99893789
#  0.99889061 0.99827226 0.99904382 0.99898718 0.99927928 0.99910212
#  0.99866656 0.99864472 0.99858273 0.99912626 0.99888273 0.99852894
#  0.99836438 0.99877813 0.99912235 0.99906958 0.99858454 0.99851101
#  0.99839724 0.99879212 0.99824897 0.99874995 0.99861194 0.99871419
#  0.99916567 0.99846681 0.99863459 0.9986926  0.99898658 0.99883576
#  0.99829753 0.99810446 0.99897909 0.99915404 0.99884441 0.99926868
#  0.99788377 0.99890747 0.99879743 0.99908368 0.99867429 0.99870483
#  0.99855571 0.99863394 0.99893762 0.99881842 0.99867073 0.99886588
#  0.9991023  0.99858101 0.99870578 0.99859353 0.99855626 0.99868755
#  0.99768885 0.9981566  0.99844586 0.99881885 0.99874833 0.99857961
#  0.99814711 0.99833319 0.99916954 0.99852129 0.99828669 0.99818664
#  0.9975613  0.99839326 0.99865082 0.99870879 0.99865276 0.99831642
#  0.9983364  0.99866    0.99830456 0.99835614 0.99828101 0.99750635
#  0.99782994 0.99812717 0.99868606 0.997998   0.99798719 0.99684543
#  0.99838613 0.99860253 0.99842887 0.99802788 0.99800227 0.99858866
#  0.99835278 0.99817975 0.99843596 0.9981969  0.99843931 0.99836949
#  0.99659692 0.99788326 0.99856958 0.99836716 0.99855666 0.99832543
#  0.99840854 0.99827819 0.99796997 0.997785   0.99810732 0.99826071
#  0.99840233 0.99703739 0.99832792 0.99786416 0.99843424 0.99776605
#  0.99829497 0.99890995 0.99819168 0.99780809 0.99802714 0.9968596
#  0.99834324 0.99811293 0.99807948 0.99796889 0.99851369 0.99826698
#  0.99678182 0.99777186 0.99773789 0.99758894 0.99768495 0.99878935
#  0.9989647  0.99804446 0.99769935 0.99756716 0.99742333 0.99839269
#  0.99743293 0.99784737 0.99739339 0.99696576 0.99834683 0.997631
#  0.99851313 0.99714584 0.99732191 0.99737762 0.99762326 0.99755435
#  0.99499277 0.99708967 0.99684844 0.99776761 0.99800355 0.99775772
#  0.99723652 0.99758208 0.99836681 0.99777271 0.99712113 0.9965377
#  0.99755311 0.99768722 0.99716415 0.99699466 0.99756825 0.99775546
#  0.99800547 0.99726729 0.99782293 0.99712644 0.99687088 0.99757555
#  0.99650273 0.99350041 0.99304106 0.99680652 0.99255441 0.99737884
#  0.99735231 0.99702247 0.99594795 0.99721247 0.99673913 0.99779134
#  0.99535358 0.99527063 0.99238441 0.9922849  0.99743849 0.99604042
#  0.99708914 0.99556029 0.99640719 0.99616455 0.99672379 0.99745104
#  0.99587629 0.99696878 0.99604696 0.99499553 0.99582046 0.99585543
#  0.99621431 0.99655546 0.99601773 0.99565725 0.99548459 0.99558724
#  0.99676887 0.99662208 0.99543632 0.99531745 0.99619193 0.99693145
#  0.99444519 0.99459057 0.99537804 0.99599072 0.99549201 0.99565705
#  0.99592382 0.99563902 0.9961412  0.99637784 0.99517111 0.99556664
#  0.99648728 0.9958298  0.99563411 0.99234836 0.98211624 0.98443416
#  0.99298169 0.98551971 0.98584262 0.99429479 0.98418887 0.98551679
#  0.99394347 0.98776299 0.98762125 0.99387917 0.98580078 0.98572066
#  0.99121491 0.98470497 0.98523253 0.99110975 0.98467026 0.98542975
#  0.99175401 0.98477564 0.98656591 0.99284175 0.98389719 0.98567357
#  0.99149331 0.9832736  0.98550725 0.99381039 0.98421492 0.98652536
#  0.99191102 0.98430141 0.9849618  0.99023453 0.98586366 0.9832273
#  0.98814528 0.98133379 0.98401346 0.98900453 0.98251779 0.9852892
#  0.98850664 0.98399811 0.98272999 0.9883016  0.9822547  0.99283843
#  0.99412079 0.99314642 0.99262921 0.9926974  0.99269358 0.99337096
#  0.99189446 0.99270897 0.99315008 0.99370679 0.99198483 0.9924474
#  0.9925729  0.9929571  0.99225548 0.9924508  0.99442379 0.99152838
#  0.98987388 0.99240293 0.99405513 0.99174388 0.99277522 0.99130198
#  0.99089352 0.99080988 0.9914997  0.99140102 0.99130671 0.99249141
#  0.99172185 0.9912748  0.99069636 0.99148737 0.99244588 0.99252905
#  0.99174097 0.99016515 0.99245895 0.99113737 0.9907847  0.99023801
#  0.99050545 0.99120315 0.99293318 0.99243473 0.99153113 0.99313925
#  0.99251105 0.99267991 0.9928856  0.99369805 0.99158485 0.992158
#  0.99125732 0.99178315 0.98996914 0.99095645 0.9894636  0.99091272
#  0.99342234 0.99103675 0.99200237 0.99142169 0.99393698 0.99277944
#  0.99327417 0.99166667 0.99222395 0.99026506 0.98989993 0.98773842
#  0.99139968 0.99249763 0.99138809 0.99112896 0.99192185 0.99229232
#  0.99238921 0.99179457 0.99194771 0.9902054  0.99082025 0.98894541
#  0.99063754 0.98953975 0.98938527 0.9897677  0.98952527 0.9887084
#  0.98975183 0.98772636 0.98892624 0.98863965 0.99018112 0.9881202
#  0.99025517 0.98955346 0.98934535 0.98870223 0.99168811 0.99159836
#  0.9913189  0.99146545 0.98991876 0.99046027 0.9901941  0.98879038
#  0.99051688 0.99138825 0.98959514 0.99015748 0.99206685 0.99132344
#  0.99114539 0.98951151 0.99268007 0.99268964 0.99183594 0.98927856
#  0.98930049 0.99055262 0.99052664 0.99009    0.98951867 0.99126183
#  0.99173731 0.99123641 0.99053887 0.99094222 0.99173298 0.98973242
#  0.99125101 0.98706177 0.99016657 0.99053206 0.98871709 0.98946184
#  0.9881186  0.98942664 0.98743773 0.99141451 0.991461   0.98853868
#  0.98876404 0.9881459  0.98762928 0.98900754 0.98896063 0.98984826
#  0.98990002 0.98858592 0.98769263 0.98872022 0.99066423 0.99148523
#  0.98883953 0.99143377 0.98888385 0.99086518 0.99185739 0.99105546
#  0.99075666 0.9888665  0.99147143 0.9909166  0.98858377 0.98855716
#  0.99000618 0.99085049 0.99062695 0.98958004 0.98925424 0.98889131
#  0.99049049 0.98840669 0.9875609  0.99115331 0.98917122 0.98883929
#  0.99068458 0.98792779 0.9906677  0.99063793 0.9886751  0.98903088
#  0.98863878 0.99022164 0.99122711 0.99048751 0.99150446 0.98900747
#  0.99118623 0.98980358 0.98931978 0.99021117 0.99164192 0.99245868
#  0.99002101 0.99058849 0.98998828 0.98999139 0.98972418 0.99082667
#  0.99167174 0.99068385 0.98867297 0.98654662 0.98851894 0.98906267
#  0.98965852 0.98767849 0.98984941 0.98948202 0.99032116 0.990129
#  0.98769974 0.98946295 0.98759191 0.99049451 0.99014053 0.98953346
#  0.99101398 0.98886341 0.98985844 0.9904511  0.98345984 0.98864302
#  0.99096774 0.99085601 0.99011284 0.99060007 0.99076531 0.99091407
#  0.99144407 0.99085299 0.99103629 0.98579576 0.98768918 0.98954586
#  0.99135597 0.99112456 0.99053695 0.99029627 0.98941633 0.99065911
#  0.99195046 0.99154066 0.98993145 0.99157134 0.98986386 0.99064965
#  0.99148768 0.98956467 0.99125619 0.99063709 0.99027197 0.98829787
#  0.98754333 0.99152997 0.98823026 0.98945079 0.98917632 0.98852285
#  0.99095645 0.98904413 0.98947264 0.98809645 0.98955194 0.99099555
#  0.98871332 0.99157216 0.98847171 0.98972641 0.98875442 0.9918922
#  0.98767507 0.99044962 0.99114566 0.9901886  0.98821656 0.99150676
#  0.98941566 0.98323449 0.99110221 0.99074477 0.99045611 0.99136842
#  0.99047619 0.99157592 0.99141719 0.99096447 0.99087285 0.99117617
#  0.99059089 0.99263566 0.99134286 0.99199027 0.99069814 0.9922683
#  0.99033618 0.99255178 0.99221232 0.99051622 0.99110918 0.98832272
#  0.98812449 0.99030644 0.99072198 0.99136406 0.99047007 0.9927477
#  0.99220992 0.98920902 0.98848891 0.98835652 0.98888176 0.99074748
#  0.98906154 0.98928243 0.99153505 0.99005625 0.9925101  0.99013626
#  0.99077994 0.99169498 0.99037527 0.99172122 0.99088331 0.99004975
#  0.99171948 0.98967211 0.99034292 0.9903952  0.98831799 0.99009804
#  0.99107314 0.99226415 0.99263209 0.99181869 0.99071606 0.99101039
#  0.99238006 0.99106536 0.99155995 0.99088268 0.98946636 0.9922496
#  0.99126183 0.99026495 0.98952551 0.99052774 0.99068387 0.98977569
#  0.99101913 0.99016979 0.99167682 0.99126183 0.99170301 0.98942484
#  0.99078198 0.99083238 0.9924812  0.98920863 0.99206971 0.99074726
#  0.99060841 0.99007673 0.99118295 0.99175107 0.99263057 0.99350847
#  0.99136459 0.99194671 0.99146294 0.98945104 0.99135475 0.99248916
#  0.99043319 0.98880836 0.99057545 0.99088472 0.99039455 0.9925066
#  0.98900766 0.99115408 0.99107612 0.99112098 0.9884058  0.99107849
#  0.98910497 0.99051914 0.98682319 0.98873768 0.99137833 0.98989779
#  0.99020781 0.98864403 0.9909612  0.99086708 0.99050804 0.99097924
#  0.99038981 0.99151067 0.98798368]

# %% [markdown]
# The "[TimeseriesGenerator](https://keras.io/api/preprocessing/timeseries/)" function accepts a sequence of data points collected at equal intervals, as well as time-series characteristics such as sequence/window length, spacing between two sequences/windows, and so on, to generate batches of time-series inputs and targets.

# %%
look_back = 30 # We could change to 60

train_generator = TimeseriesGenerator(train, train, length=look_back, batch_size=20) #change the batch size     
test_generator = TimeseriesGenerator(test, test, length=look_back, batch_size=1)

# %%
train_generator[0][1]
# Out:
# array([0.99063963, 0.99012677, 0.9909328 , 0.98626304, 0.98727803,
#        0.98984772, 0.98811724, 0.986359  , 0.98556086, 0.98783512,
#        0.98613435, 0.98939888, 0.9895648 , 0.99110591, 0.98846807,
#        0.98819198, 0.98595052, 0.98700983, 0.989085  , 0.98937536])

# %%
test_generator[0][1]
# Out:
# array([0.99598847])

# %%
print(train_generator[0][1].shape)
print(test_generator[0][1].shape)
# Out:
# (20,)
# (1,)

# %% [markdown]
# # Creating the Neural Network

# %%
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(look_back,1)))
model.add(Dense(1))
opt = tf.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='mse')
model.summary()

num_epochs = 10
history=model.fit_generator(train_generator, epochs=num_epochs, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 99/99 [==============================] - 1s 8ms/step - loss: 0.0730
# Epoch 2/10
# 99/99 [==============================] - 1s 7ms/step - loss: 3.5082e-06
# Epoch 3/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.7034e-06
# Epoch 4/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.9072e-06
# Epoch 5/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.7908e-06
# Epoch 6/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.6229e-06
# Epoch 7/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.7268e-06
# Epoch 8/10
# 99/99 [==============================] - 1s 8ms/step - loss: 2.9054e-06
# Epoch 9/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.9896e-06
# Epoch 10/10
# 99/99 [==============================] - 1s 7ms/step - loss: 2.6727e-06

# %%
train_prediction = model.predict_generator(train_generator)
train_mae_loss = np.mean(np.abs(train_prediction - train), axis=1)

plt.figure(figsize=(20,10))
plt.hist(train_mae_loss, bins=50)
plt.xlabel('Train MAE loss')
plt.ylabel('Number of Samples');

max_train_threshold = np.max(train_mae_loss)
print(f'Reconstruction error threshold: {max_train_threshold}')
# Out:
# Reconstruction error threshold: 0.006893881574838533

# %%
test_prediction = model.predict_generator(test_generator)
test_mae_loss = np.mean(np.abs(test_prediction - test), axis=1)

plt.figure(figsize=(20,10))
plt.hist(test_mae_loss, bins=50)
#plt.axvline(0.004, color='red', linestyle='--')
plt.xlabel('Test MAE loss')
plt.ylabel('Number of Samples');

max_test_threshold = np.max(test_mae_loss)
print(f'Reconstruction error threshold: {max_test_threshold}')
# Out:
# Reconstruction error threshold: 0.009165751180906005

# %%
# X_train_pred = model.predict(X_train, verbose=0)
# train_mae_loss = np.mean(np.abs(X_train_pred - X_train), axis=1)

# plt.hist(train_mae_loss, bins=50)
# plt.xlabel('Train MAE loss')
# plt.ylabel('Number of Samples');

# threshold = np.max(train_mae_loss)
# print(f'Reconstruction error threshold: {threshold}')

# %%
# X_test_pred = model.predict(X_test, verbose=0)
# test_mae_loss = np.mean(np.abs(X_test_pred-X_test), axis=1)

# plt.hist(test_mae_loss, bins=50)
# plt.xlabel('Test MAE loss')
# plt.ylabel('Number of samples');

# %%
train = train.reshape((-1))
test = test.reshape((-1))
test_prediction = test_prediction.reshape((-1))

# %%
trace1 = go.Scatter(
     y = train,
     mode = 'lines',
     name = 'Data'
 )

trace2 = go.Scatter(
     y = test,
     mode = 'lines',
     name = 'Ground Truth',
     line=dict(color='cyan', width=2)
 )

trace3 = go.Scatter(
     y = test_prediction,
     mode = 'lines',
     name = 'Prediction',
     line=dict(color='red', width=2)
 )

fig = go.Figure(data=[trace1, trace2, trace3])
fig.show()

# %%
print(f"Test Prediction Shape: {test_prediction.shape}")
print(f"Ground Thruth Shape: {test.shape}")
# Out:
# Test Prediction Shape: (969,)
# Ground Thruth Shape: (999,)

# %%
difference=np.abs(test_prediction-test[30:])
max_difference=difference.max()
max60=0.6*max_difference
sigma6=6*difference.std()

print(f"60% max difference: {round(max60,6)}")
print(f"6 sigma difference: {round(sigma6,6)}")

fig, ax2d = plt.subplots(figsize=(40,10))
ax2a = ax2d.twinx()
ax2d.plot(test_prediction, color='blue')
ax2a.plot(difference, color='red', linewidth='1')

ax2a.axhline(max60, color='green')
ax2a.axhline(sigma6, color='magenta')

ax2d.set_xlabel('Timestamp', fontsize=20)
ax2d.set_ylabel('Prediction', fontsize=20)
ax2a.set_ylabel('Difference', fontsize=20)

plt.grid()
# Out:
# 60% max difference: 0.00787
# 6 sigma difference: 0.007277

# %%
difference
# Out:
# array([7.49573740e-04, 6.30969709e-04, 1.00137254e-03, 1.05171051e-03,
#        7.64577208e-04, 1.30327894e-04, 1.30773468e-04, 1.06608025e-03,
#        3.94890881e-06, 6.36108231e-04, 6.27679118e-04, 6.95780205e-04,
#        6.15458255e-04, 7.70920881e-04, 1.20421639e-03, 5.62922130e-04,
#        1.02864258e-03, 1.09510820e-03, 1.34051559e-03, 7.16510033e-04,
#        5.43294276e-05, 6.93353666e-05, 4.10232290e-04, 1.14455429e-05,
#        1.59883880e-03, 2.36590252e-04, 3.63785224e-04, 6.52122735e-05,
#        6.60350365e-04, 1.16528766e-03, 2.96923647e-04, 1.97538924e-04,
#        5.96882886e-04, 3.09190332e-04, 5.00085389e-04, 7.49243241e-04,
#        3.99212112e-04, 5.01967533e-04, 6.13175353e-04, 9.48640577e-04,
#        4.20049149e-04, 7.51400875e-04, 4.14832814e-04, 6.09470863e-04,
#        6.88656261e-04, 2.42234978e-04, 4.06546023e-04, 7.57890445e-04,
#        4.13981202e-03, 7.23099028e-03, 2.68847793e-03, 1.75143963e-03,
#        1.50782246e-03, 1.32353805e-04, 8.90544464e-04, 5.10375805e-04,
#        7.94385403e-05, 2.53589309e-04, 7.36466585e-04, 1.30944832e-03,
#        7.27202885e-04, 7.56818928e-04, 6.96274289e-04, 9.65970132e-04,
#        4.55648602e-05, 3.08381243e-04, 3.23113564e-04, 1.10031791e-03,
#        6.16884258e-04, 9.80517074e-04, 1.17944428e-03, 6.09458503e-04,
#        8.22805649e-04, 5.26917272e-04, 1.64295698e-03, 9.14051898e-04,
#        2.59336307e-04, 2.69396844e-04, 8.79146308e-04, 9.41329600e-04,
#        6.37785009e-05, 1.20255506e-06, 8.74662833e-04, 2.63051872e-04,
#        1.48158319e-04, 1.52738646e-03, 8.91949312e-04, 9.18044638e-04,
#        6.35462176e-04, 4.29336837e-04, 3.38807471e-04, 5.19316945e-04,
#        1.06352016e-03, 8.39346615e-04, 3.97574818e-04, 7.74896503e-04,
#        5.77058285e-04, 3.43016047e-04, 4.91448924e-04, 4.37223072e-04,
#        4.27566987e-05, 1.05150209e-04, 9.77733452e-05, 8.03991739e-04,
#        2.84034202e-04, 4.18594107e-05, 2.55975369e-04, 1.86466317e-04,
#        9.84418694e-04, 1.78276112e-03, 1.17447953e-03, 4.31530652e-05,
#        1.00040326e-04, 1.31649863e-04, 2.68650128e-04, 3.69049544e-04,
#        4.00381831e-04, 7.74511880e-04, 7.25527154e-04, 2.26337312e-04,
#        1.34026112e-04, 4.05887186e-04, 1.11767760e-04, 8.00249722e-04,
#        1.38724755e-04, 2.78068886e-04, 4.58601125e-04, 2.83257165e-04,
#        6.81379359e-04, 2.03342665e-04, 1.57953394e-04, 7.91364213e-04,
#        2.56427796e-05, 4.10303295e-04, 3.37815043e-05, 2.24213781e-04,
#        1.16579519e-03, 7.21616347e-04, 4.38095377e-04, 6.93360786e-05,
#        1.20083227e-04, 1.02760253e-03, 9.22396859e-05, 2.20808034e-04,
#        3.92164970e-04, 2.39894486e-04, 1.44327492e-05, 7.72253196e-05,
#        5.03959519e-04, 5.98996896e-04, 1.10714281e-04, 3.05691755e-04,
#        9.82874898e-05, 3.47284444e-04, 3.95271892e-04, 1.18421960e-04,
#        2.80332220e-04, 4.85237848e-05, 2.80847069e-04, 1.06985532e-04,
#        1.28311034e-04, 2.06169920e-04, 3.12029498e-04, 6.57523346e-05,
#        5.74303486e-04, 4.11049020e-04, 3.70340603e-04, 1.34811347e-04,
#        2.62059876e-04, 3.77324784e-05, 5.42229114e-04, 4.00067671e-04,
#        1.17753999e-04, 8.56263578e-06, 1.32793579e-04, 4.72767352e-05,
#        3.63471115e-03, 6.07604508e-04, 1.54422740e-03, 1.67827565e-03,
#        6.44805339e-04, 8.89051481e-04, 6.26183203e-04, 7.76451113e-04,
#        9.53235585e-04, 5.26111091e-04, 9.03276659e-04, 4.98943015e-04,
#        8.64165640e-04, 7.21470895e-04, 1.24992871e-04, 6.69631017e-04,
#        2.86947515e-04, 2.84775092e-04, 5.42572046e-04, 1.99941014e-04,
#        1.20624145e-04, 3.45643680e-04, 7.00691224e-05, 3.38457569e-04,
#        2.09560252e-04, 2.35312214e-04, 3.09134597e-04, 7.54258606e-05,
#        8.05625440e-04, 4.70578877e-04, 7.61377500e-04, 3.58817417e-04,
#        3.22866087e-04, 4.93749697e-04, 4.76550815e-04, 4.48585936e-04,
#        1.11837599e-04, 2.19609165e-04, 1.85929722e-04, 3.43251729e-04,
#        5.01263003e-05, 8.55132937e-04, 6.35824617e-04, 4.83528889e-04,
#        3.43055546e-04, 7.72804910e-05, 2.62431093e-04, 6.19894927e-04,
#        6.41243115e-04, 2.80897777e-04, 8.16107516e-04, 1.32917608e-04,
#        2.34371858e-04, 2.71301588e-04, 1.56033671e-04, 3.23129058e-04,
#        2.45453022e-04, 2.93028109e-05, 2.14427784e-04, 6.61958837e-04,
#        1.70570353e-05, 9.30725011e-05, 4.77765826e-05, 9.79077878e-05,
#        1.61605805e-04, 3.51944014e-04, 1.59495099e-04, 2.29129025e-04,
#        8.21750963e-05, 3.20172791e-04, 3.89118429e-04, 2.02474661e-04,
#        5.47239081e-04, 4.57535855e-05, 2.63686731e-04, 4.55773344e-04,
#        5.86559990e-04, 1.61533611e-04, 4.13108524e-04, 2.12796751e-04,
#        4.88107161e-05, 5.59318842e-04, 3.91958553e-05, 5.13354123e-04,
#        3.99827723e-04, 7.15383917e-06, 2.82533702e-04, 7.17973097e-04,
#        4.14106105e-04, 2.36813783e-04, 4.64413459e-04, 4.60960015e-04,
#        3.10427038e-04, 2.69828608e-04, 1.07757439e-04, 4.77544025e-04,
#        2.77826723e-04, 1.96041927e-04, 9.57971904e-05, 9.81598827e-04,
#        6.91240511e-06, 2.17060226e-04, 1.80820437e-04, 5.33533441e-05,
#        1.42504942e-04, 3.86696100e-04, 3.10984493e-04, 3.26733101e-04,
#        4.94065313e-04, 3.93853599e-04, 6.57338666e-04, 4.20280392e-04,
#        4.65768054e-05, 5.17896364e-05, 1.00600434e-04, 4.62174910e-04,
#        1.77279428e-04, 1.83774466e-04, 3.15552480e-04, 1.44330576e-04,
#        4.82708904e-04, 3.87139961e-04, 1.26029508e-04, 1.72624941e-04,
#        2.56585839e-04, 1.76978969e-04, 3.74101321e-04, 1.81951185e-04,
#        3.43425818e-05, 1.45534070e-04, 5.90343640e-04, 1.61205681e-04,
#        3.94744656e-05, 1.04034818e-04, 3.98616385e-04, 2.16086538e-04,
#        3.31267786e-04, 4.74985957e-04, 4.60624851e-04, 5.96000039e-04,
#        2.36355028e-04, 6.51328098e-04, 7.91695439e-04, 3.33035505e-04,
#        1.93727395e-04, 4.71034666e-04, 2.36194505e-05, 6.54207955e-05,
#        8.08324386e-05, 1.66466498e-05, 3.29444922e-04, 1.86938477e-04,
#        3.26920883e-05, 2.36011753e-04, 4.56989925e-04, 1.03096905e-04,
#        4.61700973e-05, 6.22658119e-05, 8.13533647e-05, 6.91885871e-05,
#        9.25519978e-04, 3.42613526e-04, 7.63361451e-06, 3.77924662e-04,
#        2.80345691e-04, 9.68428268e-05, 3.31182633e-04, 9.62900931e-05,
#        7.60153674e-04, 4.26380412e-05, 1.78546684e-04, 2.45516346e-04,
#        8.30328217e-04, 1.02900405e-04, 3.59630299e-04, 3.94050570e-04,
#        3.12212585e-04, 4.27796091e-05, 2.30147724e-06, 3.33933271e-04,
#        4.45747617e-05, 2.75138832e-05, 3.73644763e-05, 7.94743350e-04,
#        3.69286474e-04, 1.97177778e-05, 5.54187406e-04, 1.78815128e-04,
#        1.52190192e-04, 1.26331875e-03, 4.31522930e-04, 6.07097280e-04,
#        3.84501224e-04, 4.00368147e-05, 4.35319688e-05, 5.62710014e-04,
#        2.79261408e-04, 9.13302782e-05, 3.52372432e-04, 9.08362534e-05,
#        3.38375101e-04, 2.44772706e-04, 1.54133009e-03, 7.32500818e-05,
#        6.27612047e-04, 3.71958747e-04, 5.39649559e-04, 2.66629692e-04,
#        3.36032730e-04, 1.83570520e-04, 1.29590999e-04, 2.87381782e-04,
#        7.85600387e-05, 2.34394662e-04, 3.61893019e-04, 1.02993402e-03,
#        3.89226406e-04, 1.07314509e-04, 4.89942589e-04, 2.19369092e-04,
#        3.46919663e-04, 9.36868157e-04, 1.32826202e-04, 2.46597480e-04,
#        1.17351226e-05, 1.14638625e-03, 4.77862543e-04, 2.03685787e-04,
#        1.65225317e-04, 5.34425710e-05, 6.07659226e-04, 3.09334331e-04,
#        1.19293611e-03, 6.10367326e-05, 8.15333387e-05, 2.04318596e-04,
#        7.00984699e-05, 1.05867389e-03, 1.13299901e-03, 1.09048428e-04,
#        2.28378910e-04, 3.23489365e-04, 4.20768518e-04, 6.07476115e-04,
#        4.06819882e-04, 7.15154711e-05, 3.81092137e-04, 7.50968479e-04,
#        7.25476747e-04, 5.66377495e-05, 8.51066570e-04, 5.94014711e-04,
#        3.29133752e-04, 2.24661577e-04, 5.91815216e-05, 1.62331954e-06,
#        2.54973317e-03, 1.54150543e-04, 3.72310704e-04, 6.08424967e-04,
#        7.97278551e-04, 4.88866274e-04, 6.13617658e-05, 3.07020662e-04,
#        1.07465267e-03, 3.80053100e-04, 2.93399503e-04, 8.27118456e-04,
#        2.95458766e-04, 4.13183494e-04, 1.37551824e-04, 2.73125520e-04,
#        3.45473489e-04, 5.09012820e-04, 7.24336580e-04, 7.67837214e-05,
#        5.07465381e-04, 2.31766153e-04, 4.46789035e-04, 3.22492208e-04,
#        7.72858656e-04, 3.67033322e-03, 3.71400577e-03, 4.63025644e-04,
#        3.83372726e-03, 1.44543086e-03, 1.27119464e-03, 8.32281595e-04,
#        2.99519232e-04, 1.02626905e-03, 4.64063105e-04, 1.49564919e-03,
#        1.08194189e-03, 1.01815107e-03, 3.77681629e-03, 3.43971534e-03,
#        2.10166346e-03, 4.85260713e-04, 1.52182316e-03, 1.40068100e-04,
#        7.59337976e-04, 4.56862331e-04, 9.96966516e-04, 1.63975775e-03,
#        8.62715171e-05, 1.04674940e-03, 2.74747424e-05, 1.00255282e-03,
#        4.78636670e-05, 5.28174460e-06, 3.85620485e-04, 7.03529462e-04,
#        1.00764912e-04, 2.58225943e-04, 3.83915342e-04, 2.30603168e-04,
#        9.96628621e-04, 7.62633956e-04, 4.82196482e-04, 5.25722686e-04,
#        4.25048757e-04, 1.13649379e-03, 1.44793271e-03, 1.12343473e-03,
#        2.02876316e-04, 4.34956865e-04, 1.01721282e-04, 1.04983804e-04,
#        3.82185380e-04, 8.11194605e-05, 5.96233337e-04, 7.90193948e-04,
#        4.79717240e-04, 4.61672574e-06, 9.38320421e-04, 1.96971983e-04,
#        6.76661929e-06, 3.26020982e-03, 1.31168741e-02, 9.34633303e-03,
#        2.02916447e-04, 7.27426400e-03, 6.08506747e-03, 3.06764313e-03,
#        7.33624635e-03, 5.11473339e-03, 3.91050150e-03, 2.64733950e-03,
#        2.40152471e-03, 4.17837335e-03, 4.30318160e-03, 3.82027414e-03,
#        2.14235196e-03, 4.55856015e-03, 3.45361184e-03, 2.85114839e-03,
#        3.84213803e-03, 2.57195920e-03, 4.08704287e-03, 3.26993221e-03,
#        1.02458077e-03, 5.41618305e-03, 4.05122791e-03, 1.73834312e-03,
#        4.31462737e-03, 4.31123315e-03, 1.51586878e-03, 6.99469548e-03,
#        3.31799375e-03, 5.88533456e-04, 4.86984587e-03, 3.21755333e-03,
#        2.14857499e-03, 3.37294477e-03, 1.31455107e-03, 3.76160308e-03,
#        1.59381973e-03, 5.34380118e-03, 2.02486487e-03, 3.20843854e-03,
#        3.56339327e-03, 3.40953674e-04, 2.93996408e-03, 1.82331776e-03,
#        2.83614918e-03, 3.07764783e-03, 3.25177769e-03, 7.74441712e-03,
#        8.20077902e-03, 6.42865688e-03, 5.26909366e-03, 4.80751255e-03,
#        4.33704503e-03, 4.55839182e-03, 2.59754232e-03, 3.16695879e-03,
#        3.25766028e-03, 3.46085128e-03, 1.39676255e-03, 1.70549300e-03,
#        1.64013303e-03, 1.86507612e-03, 9.51918957e-04, 1.03857298e-03,
#        2.91340059e-03, 3.09296060e-04, 1.93143119e-03, 8.07896449e-04,
#        2.34017083e-03, 2.33040081e-04, 8.44853439e-04, 7.33643130e-04,
#        1.05800093e-03, 1.01695291e-03, 2.22887353e-04, 3.04333100e-04,
#        3.48639598e-04, 8.73428207e-04, 4.20070642e-05, 3.66365883e-04,
#        8.69043199e-04, 4.93997832e-05, 1.03168814e-03, 1.03761672e-03,
#        1.75798778e-04, 1.38416183e-03, 1.09489197e-03, 3.18661046e-04,
#        5.96352144e-04, 1.04737701e-03, 6.34681776e-04, 1.62505174e-04,
#        1.90969739e-03, 1.23851130e-03, 2.42947591e-04, 1.86763956e-03,
#        1.06271016e-03, 1.14389131e-03, 1.25701321e-03, 1.96807987e-03,
#        3.33055457e-04, 3.10546241e-04, 6.07417730e-04, 5.73069274e-06,
#        1.79290624e-03, 5.83322968e-04, 1.99499327e-03, 2.99884241e-04,
#        2.26773328e-03, 3.35478341e-04, 7.08998945e-04, 7.61023544e-05,
#        2.61583791e-03, 1.20085688e-03, 1.60684068e-03, 1.47589048e-04,
#        4.51835003e-04, 1.53316182e-03, 1.70547517e-03, 3.66605416e-03,
#        4.15596447e-04, 1.47939015e-03, 2.45103285e-04, 5.99590778e-06,
#        8.36259650e-04, 1.14742531e-03, 1.15758971e-03, 4.75991277e-04,
#        6.12136653e-04, 1.16313089e-03, 3.85616441e-04, 2.19537098e-03,
#        2.34069247e-04, 1.28524847e-03, 1.26550445e-03, 7.18743928e-04,
#        8.52033058e-04, 1.54433386e-03, 2.95800030e-04, 2.24867704e-03,
#        7.59473391e-04, 9.28766593e-04, 7.56836608e-04, 1.33782883e-03,
#        9.98374578e-04, 2.31156970e-04, 4.83216034e-05, 5.52900209e-04,
#        2.53233673e-03, 2.19982159e-03, 1.72014863e-03, 1.72692150e-03,
#        3.74261572e-05, 6.15468464e-04, 3.12640341e-04, 1.08851279e-03,
#        7.94272514e-04, 1.61027259e-03, 3.20889063e-04, 3.19833831e-04,
#        2.22157413e-03, 1.26692243e-03, 9.82716420e-04, 7.24952956e-04,
#        2.55089747e-03, 2.29874528e-03, 1.22712992e-03, 1.43354911e-03,
#        1.23261888e-03, 1.66730879e-04, 1.33892924e-04, 2.94579716e-04,
#        8.08506388e-04, 1.05189584e-03, 1.43158911e-03, 8.08733008e-04,
#        5.71982206e-05, 4.82179410e-04, 1.24253854e-03, 8.59522604e-04,
#        7.90073377e-04, 3.45942293e-03, 6.09373582e-05, 4.32269507e-04,
#        1.39735894e-03, 4.62354900e-04, 1.73138861e-03, 1.98098187e-04,
#        2.13103980e-03, 2.11730040e-03, 1.96190967e-03, 1.12092546e-03,
#        7.21576509e-04, 1.22778727e-03, 1.57768562e-03, 1.49062530e-05,
#        6.98320371e-06, 9.41219009e-04, 9.27118106e-04, 4.44378933e-04,
#        1.24487122e-03, 4.28746779e-05, 1.94107552e-03, 2.58647977e-03,
#        2.90373356e-04, 2.38970211e-03, 3.86183902e-04, 1.68175679e-03,
#        2.52251306e-03, 1.48644782e-03, 1.06254530e-03, 9.07007804e-04,
#        1.81951603e-03, 1.08652116e-03, 1.32867987e-03, 1.18130218e-03,
#        4.15238884e-04, 1.23087597e-03, 9.03449129e-04, 2.13494841e-04,
#        4.76590388e-04, 7.53337562e-04, 9.52297741e-04, 1.21405594e-03,
#        1.89331004e-03, 1.92613101e-03, 2.44005037e-04, 5.05489962e-04,
#        1.42932589e-03, 1.45149853e-03, 1.48487373e-03, 1.31437086e-03,
#        7.53543205e-04, 2.70499576e-04, 5.98114459e-04, 1.08143023e-03,
#        2.00547575e-03, 1.08265770e-03, 2.02772249e-03, 6.49514155e-04,
#        1.64338787e-03, 1.09227927e-04, 3.52697692e-04, 6.10575847e-04,
#        2.00538194e-03, 2.62883941e-03, 6.47722172e-05, 5.50690950e-04,
#        8.45622503e-05, 4.26533455e-05, 2.80602678e-04, 8.76903845e-04,
#        1.64878755e-03, 5.13545385e-04, 1.52337623e-03, 3.46077938e-03,
#        1.08397965e-03, 4.08168605e-04, 2.58784407e-04, 1.70961908e-03,
#        6.83393042e-04, 2.74630673e-04, 1.12867565e-03, 8.47520530e-04,
#        1.63490729e-03, 3.43003417e-04, 1.53506854e-03, 1.57978355e-03,
#        1.08602478e-03, 4.10711151e-04, 1.88550784e-03, 4.32009994e-04,
#        6.52782299e-04, 1.20390019e-03, 5.88273117e-03, 6.11382728e-06,
#        2.33661267e-03, 2.00994608e-03, 1.09827661e-03, 1.51141106e-03,
#        1.54910308e-03, 1.56601284e-03, 1.96548535e-03, 1.19844554e-03,
#        1.28906585e-03, 4.06811228e-03, 1.70584236e-03, 3.41396966e-04,
#        2.13481186e-03, 1.70515806e-03, 9.66271151e-04, 6.59971362e-04,
#        2.56871167e-04, 1.04635183e-03, 2.24984899e-03, 1.62224694e-03,
#        1.29417721e-04, 1.54921970e-03, 3.02806427e-04, 5.48376404e-04,
#        1.34723885e-03, 6.91105628e-04, 1.10413254e-03, 3.87034262e-04,
#        1.05310185e-05, 1.95712587e-03, 2.47122551e-03, 1.81146996e-03,
#        1.66508485e-03, 2.18176868e-04, 4.39837841e-04, 1.00843058e-03,
#        1.57502082e-03, 4.73504109e-04, 5.42513793e-05, 1.29302988e-03,
#        3.28697113e-04, 1.75895511e-03, 6.78127829e-04, 2.30683422e-03,
#        1.01260206e-03, 4.01422892e-04, 5.85410584e-04, 2.65244823e-03,
#        1.82187631e-03, 1.20605207e-03, 1.80076973e-03, 6.84080845e-04,
#        1.31632743e-03, 2.15334478e-03, 1.48643575e-04, 6.26609317e-03,
#        2.32076115e-03, 1.71810783e-03, 1.29163757e-03, 2.10911844e-03,
#        1.02043095e-03, 2.04088575e-03, 1.69862966e-03, 1.08909078e-03,
#        9.11165599e-04, 1.14033334e-03, 4.56175950e-04, 2.48061770e-03,
#        9.37184146e-04, 1.51502928e-03, 7.50827393e-05, 1.66306493e-03,
#        4.27665410e-04, 1.86208555e-03, 1.33772835e-03, 4.79724126e-04,
#        1.92633403e-04, 2.60283284e-03, 2.48682665e-03, 2.75328355e-05,
#        4.08449343e-04, 1.04045886e-03, 6.79692718e-05, 2.36759338e-03,
#        1.60415056e-03, 1.53765566e-03, 2.07555803e-03, 1.95826441e-03,
#        1.19561455e-03, 8.25670705e-04, 9.15520141e-04, 5.52769296e-04,
#        1.79831115e-03, 1.60128848e-04, 2.64295072e-03, 1.72219360e-05,
#        7.07572094e-04, 1.57659488e-03, 1.24918309e-04, 1.49792825e-03,
#        5.28112706e-04, 3.29880276e-04, 1.41102119e-03, 7.67061850e-04,
#        2.91563274e-05, 1.08787744e-04, 1.95095738e-03, 7.59759604e-05,
#        1.05870878e-03, 2.15899881e-03, 2.32571178e-03, 1.29893271e-03,
#        9.31207820e-05, 4.09927503e-04, 1.76498658e-03, 2.87568296e-04,
#        7.78467400e-04, 3.27649199e-05, 1.36626490e-03, 1.58625292e-03,
#        4.42915183e-04, 5.72202939e-04, 1.22415176e-03, 5.94347030e-05,
#        1.25956672e-04, 7.59985295e-04, 5.97301543e-04, 2.88872819e-04,
#        1.28764863e-03, 7.59415847e-04, 1.15761828e-03, 1.21442852e-03,
#        3.09005857e-04, 3.52909073e-04, 1.99017041e-03, 1.47039256e-03,
#        1.59059657e-03, 1.06082678e-04, 8.56561824e-06, 5.08064364e-04,
#        6.88881273e-04, 1.21444012e-03, 1.99737745e-03, 2.69086297e-03,
#        2.87886999e-04, 8.81802967e-04, 3.23708292e-04, 1.69528141e-03,
#        4.18113051e-04, 1.51902215e-03, 6.72899336e-04, 2.18842158e-03,
#        1.59781006e-04, 1.81493363e-04, 3.01287579e-04, 1.87668488e-03,
#        1.80237228e-03, 5.83597930e-04, 4.61880084e-04, 4.93389851e-04,
#        2.24157848e-03, 7.12504675e-04, 1.32222883e-03, 2.72600813e-04,
#        3.42417763e-03, 1.09001067e-03, 1.68701531e-03, 6.04409375e-05,
#        4.14094129e-04, 1.15690034e-03, 1.32525493e-03, 1.11985123e-03,
#        6.86363371e-04, 1.12901832e-03, 4.63766544e-04, 1.57193012e-03,
#        2.09035424e-03])

# %%
n=0
a=0

new_anomalies_60percentmax=[]

for i in range(len(difference)):
    if difference[i] <= max60:
        n=n+1
        t=0
        new_anomalies_60percentmax.append(t)
        
    elif difference[i] > max60:
        a=a+1
        t=1
        new_anomalies_60percentmax.append(t)

        

print("Number of anomalies after using 60% Max Threshold:")   
print("#################################################:")   
print(f"Number of no anomalies: {n}")
print(f"Number of anomalies: {a}")
# Out:
# Number of anomalies after using 60% Max Threshold:
# #################################################:
# Number of no anomalies: 966
# Number of anomalies: 3

# %%
n=0
a=0

new_anomalies_6sigma=[]

for i in range(len(difference)):
    if difference[i] <= sigma6:
        n=n+1
        t=0
        new_anomalies_6sigma.append(t)
        
    elif difference[i] > sigma6:
        a=a+1
        t=1
        new_anomalies_6sigma.append(t)

        

print("Number of anomalies after using 6 Sigma Threshold:")   
print("#################################################:")   
print(f"Number of no anomalies: {n}")
print(f"Number of anomalies: {a}")
# Out:
# Number of anomalies after using 6 Sigma Threshold:
# #################################################:
# Number of no anomalies: 964
# Number of anomalies: 5

# %%
used_time=timestamp[5002:8001]

print(len(difference))
print(len(new_anomalies_60percentmax))
# Out:
# 969
# 969

# %%
tp60m=0
fp60m=0
tn60m=0
fn60m=0

for i in range(len(difference)):
    if new_anomalies_60percentmax[i] == 1 and label2[i+5002] == 1:
            tp60m=tp60m+1
    elif new_anomalies_60percentmax[i] == 1 and label2[i+5002] != 1:
            fp60m=fp60m+1
    elif new_anomalies_60percentmax[i] != 1 and label2[i+5002] == 1:
            fn60m=fn60m+1
    elif new_anomalies_60percentmax[i] != 1 and label2[i+5002] != 1:
            tn60m=tn60m+1
            
print("THIS IS FROM USING THE THRESHOLD AS 60% OF THE MAXIMUM VALUES OF THE MOVING AVERAGE")
print("###################################################################################")
print(f"Number of True Positives: {tp60m}")
print(f"Number of False Positives: {fp60m}")
print(f"Number of True Negatives: {tn60m}")
print(f"Number of False Negatives: {fn60m}")
print("###################################")

precision_60m=tp60m/(tp60m+fp60m)
print(f"Precision: {round(precision_60m,3)}")

recall_60m=tp60m/(tp60m+fn60m)
print(f"Recall: {round(recall_60m,3)}")

F1_Score_60m=(2*precision_60m*recall_60m)/(precision_60m+recall_60m)
print(f"F1 Score: {round(F1_Score_60m,3)}")
# Out:
# THIS IS FROM USING THE THRESHOLD AS 60% OF THE MAXIMUM VALUES OF THE MOVING AVERAGE
# ###################################################################################
# Number of True Positives: 0
# Number of False Positives: 3
# Number of True Negatives: 966
# Number of False Negatives: 0
# ###################################
# Precision: 0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/vj/779818pj4tz4xwpyg2yk0mq00000gn/T/ipykernel_84226/4197757733.py in <module>
#      25 print(f"Precision: {round(precision_60m,3)}")
#      26
# ---> 27 recall_60m=tp60m/(tp60m+fn60m)
#      28 print(f"Recall: {round(recall_60m,3)}")
#      29
#
# ZeroDivisionError: division by zero

# %%
tp6s=0
fp6s=0
tn6s=0
fn6s=0

for i in range(len(difference)):
    if new_anomalies_6sigma[i] == 1 and label2[i+5002] == 1:
            tp6s=tp6s+1
    elif new_anomalies_6sigma[i] == 1 and label2[i+5002] != 1:
            fp6s=fp6s+1
    elif new_anomalies_6sigma[i] != 1 and label2[i+5002] == 1:
            fn6s=fn6s+1
    elif new_anomalies_6sigma[i] != 1 and label2[i+5002] != 1:
            tn6s=tn6s+1
            
print("THIS IS FROM USING THE THRESHOLD AS 6 Sigma VALUES OF THE MOVING AVERAGE")
print("###################################################################################")
print(f"Number of True Positives: {tp6s}")
print(f"Number of False Positives: {fp6s}")
print(f"Number of True Negatives: {tn6s}")
print(f"Number of False Negatives: {fn6s}")
print("###################################")

precision_6s=tp6s/(tp6s+fp6s)
print(f"Precision: {round(precision_6s,3)}")

recall_6s=tp6s/(tp6s+fn6s)
print(f"Recall: {round(recall_6s,3)}")

F1_Score_6s=(2*precision_6s*recall_6s)/(precision_6s+recall_6s)
print(f"F1 Score: {round(F1_Score_6s,3)}")
# Out:
# THIS IS FROM USING THE THRESHOLD AS 6 Sigma VALUES OF THE MOVING AVERAGE
# ###################################################################################
# Number of True Positives: 0
# Number of False Positives: 5
# Number of True Negatives: 964
# Number of False Negatives: 0
# ###################################
# Precision: 0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/vj/779818pj4tz4xwpyg2yk0mq00000gn/T/ipykernel_84226/3110186615.py in <module>
#      25 print(f"Precision: {round(precision_6s,3)}")
#      26
# ---> 27 recall_6s=tp6s/(tp6s+fn6s)
#      28 print(f"Recall: {round(recall_6s,3)}")
#      29
#
# ZeroDivisionError: division by zero

# %%
fig, ax2d = plt.subplots(figsize=(40,10))
ax2a = ax2d.twinx()
ax2d.plot(new_anomalies_60percentmax, color='blue')
ax2a.plot(label2[5002:8001], color='red', linewidth='1')

ax2d.set_xlabel('Timestamp', fontsize=20)
ax2d.set_ylabel('Prediction', fontsize=20)
ax2a.set_ylabel('Difference', fontsize=20)

plt.grid()

# %% [markdown]
# 1. **"close_train"** is the data set used for the training using a certain percentage to split the dataset
# 2. **"prediction"** speaks for itself, it is basicaly predicting what will happen on the testing data
# 3. **"close_test"** is the data set used for the testing using the remaining percentage to compare with the prediction, also known as the "Ground Truth"

# %% [markdown]
# # Forecasting

# %%
kpi=huwaei['kpi_value']
kpi=np.array(kpi)
kpi = kpi.reshape((-1))

# %%
kpi.shape

# %%
def predict(num_prediction, model):
    prediction_list = train[-(look_back):]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list

# %%
# def predict_dates(num_prediction):
#     prediction_dates = timestamp[len(close_train)+1:len(close_train)+num_prediction+1] 
#     return prediction_dates
    
# def predict_dates(num_prediction):
#     last_date = df['Time'].values[-1]
#     prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
#     return prediction_dates

# %%
num_prediction = len(test)-1
print(f"Number for predictions: {num_prediction}")

# %%
print("Forecast")
forecast = predict(num_prediction, model)
forecast

# %%
# print("Forecast Dates")
# forecast_dates = predict_dates(num_prediction)
# print(forecast_dates)

# %%
# def predict_dates(num_prediction):
#     prediction_dates = df['Time'][len(close_train)+1:len(close_train)+num_prediction+1] 
#     return prediction_dates

# predict_dates(5)

# %%
# df['Time'].values[-400]

# %%
plt.plot(forecast)

# %%
trace1 = go.Scatter(
    y = train,
    mode = 'lines',
    name = 'Data'
)

trace3 = go.Scatter(
    y = forecast,
    mode = 'lines',
    name = 'Forecast'
)

layout = go.Layout(
    title = "Huwaei Prediction",
    yaxis = {'title' : "KPI Value"}
)
fig = go.Figure(data=[trace1, trace3], layout=layout)
fig.show()

# %% [markdown]
# This prediction behavior is normal because of the propogation from the small error in the begining to propogate into a larger error during the forecast phase
